# %%
img_path = "class room pose.v1i.yolov8/train/images/" + os.listdir("class room pose.v1i.yolov8/train/images")[10]
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

results = pose_model(img_path)

img_pose = results[0].plot()
img_pose = cv2.cvtColor(img_pose, cv2.COLOR_BGR2RGB)

# show side by side
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(img_pose)
plt.title("With Keypoints")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# image 1/1 c:\Codes\Computer_Vision\skripsi\class room pose.v1i.yolov8\train\images\195_jpg.rf.62349a0c459b0ad7e8bc0985e6ef8f28.jpg: 640x640 2 persons, 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 12.8ms postprocess per image at shape (1, 3, 640, 640)
